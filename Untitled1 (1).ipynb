# %%
"""#HANOİ KULELERİ
def printMove(fr, to):
    print('move from ' + str(fr) + ' to ' + str(to))

def Towers(n, fr, to, spare):
    if n == 1:
        printMove(fr, to)
    else:
        Towers(n-1, fr, spare, to)
        Towers(1, fr, to, spare)
        Towers(n-1, spare, to, fr)

Towers(3, 'A', 'C', 'B')

Çıktı:
move from A to C
move from A to B
move from C to B
move from A to C
move from B to A
move from B to C
move from A to C"""

#--------------------------------------#
"""def fib(x):
    if x == 0:
        return 0
    elif x == 1:
        return 1
    else:
        return fib(x-1) + fib(x-2)

print(fib(10))


#rekürsif şekli
def fib_efficient(n, d):
    if n in d:
        return d[n]
    elif n == 0:
        d[n] = 0
        return 0
    elif n == 1:
        d[n] = 1
        return 1
    else:
        ans = fib_efficient(n-1, d) + fib_efficient(n-2, d)
        d[n] = ans
        return ans

d = {}
print(fib_efficient(10, d))"""

#--------------------------------------#
"""try:
    a = int(input("Bir sayı söyleyin: "))
    b = int(input("Başka bir sayı söyleyin: "))
    print(a / b)
except ValueError:
    print("Geçersiz giriş. Lütfen bir sayı giriniz.")
except ZeroDivisionError:
    print("Bir sayıyı sıfıra bölemezsiniz.")"""

#--------------------------------------#
"""Bir nesne örneği oluşturmayı tanımlamak için özel bir yöntem olan `__init__` kullanılır

 class Coordinate(object):
 def __init__(self, x, y):
 self.x = x
 self.y = y

- `self` parametresi Python tarafından otomatik olarak geçirilir"""

#--------------------------------------#
"""class Coordinate(object):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def distance(self, other):
        x_diff_sq = (self.x - other.x) ** 2
        y_diff_sq = (self.y - other.y) ** 2
        return (x_diff_sq + y_diff_sq) ** 0.5"""

#--------------------------------------#
