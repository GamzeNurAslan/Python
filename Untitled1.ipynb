# %%
"""#operatörler
x = 5
y = 7
#toplama
print(x+y)
#çıkarma
print(x-y)
#çarpma
print(x*y)
#bölme
print(x/y)"""

#-------------------------#
"""pi = 3.14
radius = 2
area = pi*radius*radius
print(area)"""

#-------------------------#
"""text = input("Bir şey yazın : ")
print(3*text)"""

#-------------------------#
"""gun_vakti = 15
uyku_vakti = 7
print(uyku_vakti>gun_vakti)

derive = True
drink = False
both = drink or derive
print(both)"""

#--------------------------#
"""x = float(input("x için bir sayı girin : "))
y = float(input("y için bir sayı girin : "))

if x == y:
    print("x ve y eşittir")

    if y != 0:
        print("bu yüzden, x/y = ", x / y)
elif x < y:
    print("x daha küçük")
else:
    print("y daha küçük")"""

#---------------------------#
"""metin = "gamzenaslan"
len(metin)"""

#---------------------------#
"""metin = "gamzenaslan"
metin[0]
metin[-4]
#metin[12]"""

#---------------------------#
"""kelime = "abcdefghj"
kelime[3:6]
kelime[3:6:2]
kelime[::]
kelime[::-1]
kelime[4:1:-2]"""

#---------------------------#
"""s = "gamzenaslan"
s[0] = 'k'
s = 'k'+s[1:len(s)]
#Hata verir"""

#---------------------------#
"""s = "gamzenaslan"
for index in range(len(s)):
    if s[index] == 'a' or s[index] == 'n':
        print("Bir 'a' veya 'n' var")


for char in s:
    if char == 'a' or char == 'n':
        print("Bir 'a' veya 'n' var")"""

#---------------------------#
"""sayi = 8

for tahmin in range(sayi+1):
      if tahmin**3 == sayi:
        print("Küp kökü ",sayi," olan sayı = ",tahmin)"""

#---------------------------#
"""TUPLES(DEMETLER)
Sıralı bir eleman dizisidir,eleman türleri karışık olabilir.Eleman değerleri değiştirilemez.(immutable).Parantez ile temsil edilir.
t = (2,"mit",3)
t[0]
(2,"mit",3)+(5,6)
t[1,2]
t[1,3]
len(t)
t[1] = 4"""

#----------------------------#
"""def get_data(aTuple):
    nums = []
    words = set()

    for t in aTuple:
        nums.append(t[0])
        words.add(t[1])

    if nums:
        min_n = min(nums)
        max_n = max(nums)
    else:
        min_n = max_n = None

    unique_words = len(words)

    return (min_n, max_n, unique_words)"""

#-----------------------------------#
"""a_list = []
L = [2, 'a', 4, [1,2]]

len(L) # Sonuç: 4
L[0] # Sonuç: 2
L[2]+1 # Sonuç: 5
L[3] # Sonuç: [1,2], başka bir liste!
#L[4] # Hata verir
i = 2
L[i-1] # Sonuç: 'a' çünkü L[1]='a'"""

#----------------------------------#
"""total = 0
L = [2 , 3 , 4, 7]
for i in range(len(L)):
 total += L[i]
 print(total)
 total = 0
for i in L:
 total += i
 print(total)"""

#----------------------------------#
"""L = [2,1,3]
L.append(5) # L artık [2,1,3,5]
print(L)"""

#----------------------------------#
"""L1 = [2,1,3]
L2 = [4,5,6]
L3 = L1 + L2 # L3 [2,1,3,4,5,6]
print(L3)"""

#----------------------------------#
"""Belirli bir indisteki elemanı silmek için `del(L[index])` kullanılır
- Listenin sonundaki elemanı çıkarmak için `L.pop()` kullanılır, çıkarılan elemanı
döndürür
- Belirli bir elemanı çıkarmak için `L.remove(element)` kullanılır
Stringi bir karakter üzerinde bölmek için `s.split()` kullanılır
 s = "I<3 cs" # s bir string
 list(s) # ['I', '<', '3', ' ', 'c', 's'] """

#----------------------------------#
"""def mult_iter(a, b):
    sonuc = 0
    while b > 0:
        sonuc += a
        b -= 1
    return sonuc
print(mult_iter(4,3))"""

#----------------------------------#
"""def mult(a, b):
   if b == 1:
     return a
   else:
     return a * mult(a, b-1)
print(mult(5,3))"""

#----------------------------------#
"""def fact(n):
 if n == 1:
   return 1
 else:
   return n * fact(n-1)
print(fact(5))

#İkinci yontem
def factorial_iter(number):
 prod = 1
 for i in range(1, number+1):
     prod *= i
 return prod
 print(factorial_iter(6))"""

#----------------------------------#
