# %%
"""hi = "merhaba"
isim = "ana"
selamla = hi + isim
print(selamla)
selamlama = hi + " " + isim
print(selamlama)
komik = hi + (" " + isim)*3
print(komik)
#Çıktı
merhabaana
merhaba ana
merhaba ana ana ana"""

#----------------------------------#
"""n = 0
while n < 5:
    print(n)
    n = n+1
#Çıktı
0
1
2
3
4"""

#----------------------------------#
"""for n in range(5):
    print(n)"""

#----------------------------------#
"""total = 0
for i in range(10):
  total += i
print(total)"""

#---------------------------------#
"""toplam = 0
for i in range(5, 11, 2):
    toplam += i
    if toplam == 5:
        break
        toplam += 1
print(toplam)"""

#---------------------------------#
"""#mükemmel_kareler
cevap = 0
negatif_bayrak = False
x = int(input("Bir tamsayı girin: "))
if x < 0:
    negatif_bayrak = True
while cevap**2 < x:
    cevap = cevap + 1
if cevap**2 == x:
    print(x, "sayısının karekökü", cevap)
else:
    print(x, "mükemmel bir kare değildir")
    if negatif_bayrak:
        print("Sadece kontrol ediyorum... demek istediğiniz", -x, "mı?")"""

#---------------------------------#
"""sesli_harfler = "aefhilmnorsxAEFHILMNORSX"
kelime = input("Sana tezahürat yapacağım! Bir kelime gir: ")
seviyeler = int(input("Tezahürat seviyesi (1-10): "))

i = 0
while i < len(kelime):
    karakter = kelime[i]
    if karakter in sesli_harfler:
        print("Bana bir " + karakter + " ver! " + karakter)
    else:
        print("Bana bir " + karakter + " ver! " + karakter)
    i += 1
print("Bu ne anlama geliyor?")
for i in range(seviyeler):
    print(kelime, "!!!")"""

#-----------------------------------------#
"""#for döngüsüyle kullanımı
sesli_harfler = "aefhilmnorsxAEFHILMNORSX"
kelime = input("Sana tezahürat yapacağım! Bir kelime gir: ")
seviyeler = int(input("Tezahürat seviyesi (1-10): "))

i = 0
for i in range(len(kelime)):
    karakter = kelime[i]
    if karakter in sesli_harfler:
        print("Bana bir " + karakter + " ver! " + karakter)
    else:
        print("Bana bir " + karakter + " ver! " + karakter)
    i += 1
print("Bu ne anlama geliyor?")
for i in range(seviyeler):
    print(kelime, "!!!")"""

#--------------------------------------#
"""kup = 27

for tahmin in range(abs(kup)+1):
    if tahmin**3 >= abs(kup):
        break

if tahmin**3 != abs(kup):
    print(kup, 'mükemmel bir küp değil')

else:
    if kup < 0:
        tahmin = -tahmin
    print(kup, "sayısının küp kökü", tahmin)"""

#-------------------------------------#
"""kup = 27
hata = 0.01
tahmin_sayisi = 0
alt = 0
üst = kup
tahmin = (üst + alt)/2.0
while abs(tahmin**3 - kup) >= hata:
    if tahmin**3 < kup:
        alt = tahmin
    else:
        üst = tahmin
    tahmin = (üst + alt)/2.0
    tahmin_sayisi += 1
print('tahmin sayısı =', tahmin_sayisi)
print(tahmin, kup, "sayısının küp köküne yakındır.")"""

#------------------------------------#
"""def cift_mi_return_ile(i):
    print('return ile')
    kalan = i % 2
    return kalan == 0

cift_mi_return_ile(3)
print(cift_mi_return_ile(3))

def cift_mi_return_olmadan(i):
    print('return olmadan')
    kalan = i % 2

cift_mi_return_olmadan(3)
print(cift_mi_return_olmadan(3))

def cift_mi(i):
    kalan = i % 2
    return kalan == 0

print("0 ile 20 arasındaki tüm sayılar: çift mi değil mi")
for i in range(20):
    if cift_mi(i):
        print(i, "çift")
    else:
        print(i, "tek")"""

#-------------------------------------#
"""#fonksiyon kullanımı
def fonk_a():
    print('fonksiyon a içinde')

def fonk_b(y):
    print('fonksiyon b içinde')
    return y

def fonk_c(z):
    print('fonksiyon c içinde')
    return z()

print(fonk_a())
print(5+fonk_b(2))
print(fonk_c(fonk_a))"""

#------------------------------------#
"""def f():
    def x(a, b):
        return a+b
    return x
val = f()(3,4)
print(val)"""

#-----------------------------------#
"""def f(x):
   x = x + 1
   print('f(x) içinde: x =', x)
   return x

x = 3
z = f(x)
print('ana program kapsamı içinde: z =', z)
print('ana program kapsamı içinde: x =', x)

def g(x):
    def h(x):
        x = x+1
        print("h(x) içinde: x =", x)
    x = x + 1
    print('g(x) içinde: x =', x)
    h(x)
    return x

x = 3
z = g(x)
print('ana program kapsamı içinde: x =', x)
print('ana program kapsamı içinde: z =', z)"""

#----------------------------------------#
"""def veri_al(aTuple):

    aTuple, tuple içinde tuple'lardan oluşur (int, string)
    aTuple'daki tüm tamsayıları çıkarır ve bunları yeni bir tuple
    içindeki elemanlar olarak ayarlar.
    aTuple'daki tüm benzersiz string'leri çıkarır ve
    bunları yeni bir tuple içindeki elemanlar olarak ayarlar.
    Bir tuple olarak en küçük tamsayıyı, en büyük tamsayıyı ve
    benzersiz string'lerin sayısını döndürür.

    sayilar = ()  # boş tuple
    kelimeler = ()
    for t in aTuple:
        # singleton tuple ile birleştirme
        sayilar = sayilar + (t[0],)
        # daha önce eklemediğimiz kelimeleri ekle
        if t[1] not in kelimeler:
            kelimeler = kelimeler + (t[1],)
    min_sayi = min(sayilar)
    max_sayi = max(sayilar)
    benzersiz_kelimeler = len(kelimeler)
    return (min_sayi, max_sayi, benzersiz_kelimeler)

test = ((1,"a"), (2, "b"),
        (1,"a"), (7,"b"))
(a, b, c) = veri_al(test)
print("a:", a, "b:", b, "c:", c)

# istediğiniz herhangi bir veri üzerinde uygulayın!
tswift = ((2014,"Katy"),
          (2014, "Harry"),
          (2012,"Jake"),
          (2010,"Taylor"),
          (2008,"Joe"))
(min_yil, max_yil, kisi_sayisi) = veri_al(tswift)
print("From", min_yil, "to", max_yil, \
        "Taylor Swift", kisi_sayisi, "kişiler hakkında şarkı yazdı!")
#Çıktı
a: 1 b: 7 c: 2
From 2008 to 2014 Taylor Swift 5 kişiler hakkında şarkı yazdı!"""

#-----------------------------------------#
"""myList = [1, 2, 3]
myList.insert(1, 'new number')
print(myList)"""

#-----------------------------------------#
"""L1 = [2, 1, 3]
L2 = [4, 5, 6]
L3 = L1 + L2
L1.extend([0, 6])

L = [2, 11, 3, 6, 3, 7, 0]
L.remove(2)
L.remove(3)
del(L[1])
print(L.pop())

s = "Ben<3 Python"
print(list(s))
print(s.split('<'))
L = ['a', 'b', 'c']
print(''.join(L))
print('_'.join(L))

L = [9, 6, 0, 3]
print(sorted(L))
L.sort()
L.reverse()"""

#----------------------------------------#
"""#aliasing (takma ad)
a = 1
b = a
print(a)
print(b)

sicak = ['kırmızı', 'sarı', 'turuncu']
ates = sicak
ates.append('pembe')
print(ates)
print(sicak)"""

#########################################

"""#klonlama
serin = ['mavi', 'yeşil', 'gri']
rahat = serin[:]
rahat.append('siyah')
print(rahat)
print(serin)"""

#---------------------------------------#
"""#şarkı sözlerinden kaçar tane geçtiğini bulmak
def sozleri_frekanslara_cevir(sozler):
    sozluk = {}
    for kelime in sozler:
        if kelime in sozluk:
            sozluk[kelime] += 1
        else:
            sozluk[kelime] = 1
    return sozluk


she_loves_you = ['she', 'loves', 'you', 'yeah', 'yeah',
'yeah','she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',

'you', 'think', "you've", 'lost', 'your', 'love',
'well', 'i', 'saw', 'her', 'yesterday-yi-yay',
"it's", 'you', "she's", 'thinking', 'of',
'and', 'she', 'told', 'me', 'what', 'to', 'say-yi-yay',

'she', 'says', 'she', 'loves', 'you',
'and', 'you', 'know', 'that', "can't", 'be', 'bad',
'yes', 'she', 'loves', 'you',
'and', 'you', 'know', 'you', 'should', 'be', 'glad',

'she', 'said', 'you', 'hurt', 'her', 'so',
'she', 'almost', 'lost', 'her', 'mind',
'and', 'now', 'she', 'says', 'she', 'knows',
"you're", 'not', 'the', 'hurting', 'kind',

'she', 'says', 'she', 'loves', 'you',
'and', 'you', 'know', 'that', "can't", 'be', 'bad',
'yes', 'she', 'loves', 'you',
'and', 'you', 'know', 'you', 'should', 'be', 'glad',

'oo', 'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',

'you', 'know', "it's", 'up', 'to', 'you',
'i', 'think', "it's", 'only', 'fair',
'pride', 'can', 'hurt', 'you', 'too',
'pologize', 'to', 'her',

'Because', 'she', 'loves', 'you',
'and', 'you', 'know', 'that', "can't", 'be', 'bad',
'Yes', 'she', 'loves', 'you',
'and', 'you', 'know', 'you', 'should', 'be', 'glad',

'oo', 'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',
'yeah', 'yeah', 'yeah',
'yeah', 'yeah', 'yeah', 'yeah'
]

beatles = sozleri_frekanslara_cevir(she_loves_you)


def en_sik_kelimeler(freqs):
    degerler = freqs.values()
    en_iyi = max(freqs.values())
    kelimeler = []
    for k in freqs:
        if freqs[k] == en_iyi:
            kelimeler.append(k)
    return (kelimeler, en_iyi)

def sık_gecen_kelimeler(freqs, minKere):
    sonuc = []
    bitti_mi = False
    while not bitti_mi:
        gecici = en_sik_kelimeler(freqs)
        if gecici[1] >= minKere:
            sonuc.append(gecici)
            for w in gecici[0]:
                del(freqs[w])  #kelimeyi sözlükten sil
        else:
            bitti_mi = True
    return sonuc

print(sık_gecen_kelimeler(beatles, 5))"""

#-----------------------------------------------#
"""#diziyi ters döndürme
def listeyi_ters_cevir(L):
    for i in range(len(L)//2):
        j = len(L) - i - 1
        temp = L[i]
        L[i] = L[j]
        L[j] = temp

L = [1, 2, 3, 4]
listeyi_ters_cevir(L)
print(L)"""

#----------------------------------------------#
"""#asal_sayı_bulma
def asal_sayilar_listesi(n):
    primes = [2]
    for j in range(3, n+1):
        bolunuyor_mu = False
        for p in primes:
            if j % p == 0:
                bolunuyor_mu = True
        if not bolunuyor_mu:
            primes.append(j)
    return primes

print(asal_sayilar_listesi(2))
print(asal_sayilar_listesi(31))"""

#----------------------------------------#
"""try:
    a = int(input("Bana bir sayı söyle: "))
    b = int(input("Bana başka bir sayı söyle: "))
    print("a/b = ", a / b)
except:
    print("Kullanıcı girdisinde hata.")


try:
    a = int(input("Bana bir sayı söyle: "))
    b = int(input("Bana başka bir sayı söyle: "))
    print("a/b = ", a / b)
    print("a+b = ", a + b)
except ValueError:
    print("Sayıya dönüştürülemedi.")
except ZeroDivisionError:
    print("Sıfıra bölünemez")
except:
    print("Bir şeyler çok ters gitti.")"""

#-----------------------------------------#
"""class Koordinat(object):
    #x ve y değerlerinden oluşan bir koordinat
    def __init__(self, x, y):
        # x ve y değerlerini ayarlar
        self.x = x
        self.y = y
    def __str__(self):
        #Kendinin string temsilini döndürür
        return "<" + str(self.x) + "," + str(self.y) + ">"
    def mesafe(self, diğer):
        #İki nokta arasındaki öklid mesafesini döndürür
        x_fark_kare = (self.x - diğer.x)**2
        y_fark_kare = (self.y - diğer.y)**2
        return (x_fark_kare + y_fark_kare)**0.5


c = Koordinat(3, 4)
orijin = Koordinat(0, 0)
print(c.x, orijin.x)
print(c.mesafe(orijin))
print(Koordinat.mesafe(c, orijin))
print(orijin.mesafe(c))
print(c)"""

#-----------------------------------------#
"""class Kesir(object):

    #Bir sayı bir kesir olarak temsil edilir

    def __init__(self, pay, payda):
        # pay ve payda tamsayılar olmalı
        assert type(pay) == int and type(payda) == int, "tamsayılar kullanılmadı"
        self.pay = pay
        self.payda = payda
    def __str__(self):
        #Kendinin string temsilini döndürür
        return str(self.pay) + "/" + str(self.payda)
    def __add__(self, diğer):
        #Toplama işlemi için yeni bir kesir döndürür
        üst = self.pay * diğer.payda + self.payda * diğer.pay
        alt = self.payda * diğer.payda
        return Kesir(üst, alt)
    def __sub__(self, diğer):
        #Çıkarma işlemi için yeni bir kesir döndürür
        üst = self.pay * diğer.payda - self.payda * diğer.pay
        alt = self.payda * diğer.payda
        return Kesir(üst, alt)
    def __float__(self):
        #Kesirin ondalık değerini döndürür
        return self.pay / self.payda
    def ters(self):
        #1/kesir'i temsil eden yeni bir kesir döndürür
        return Kesir(self.payda, self.pay)

a = Kesir(1, 4)
b = Kesir(3, 4)
c = a + b  # c = Kesir nesnesi
print(c)
print(float(c))
print(Kesir.__float__(c))
print(float(b.ters()))"""

#----------------------------------------------#
# Out:
# 16/16
# 1.0
# 1.0
# 1.3333333333333333
